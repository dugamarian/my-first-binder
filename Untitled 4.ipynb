# %%
library(dplyr)
library(tidyverse)
library(downloader)

# %%
install.packages("downloader")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
load("skew.RData")
dim(dat)
par(mfrow = c(3,3))
# Out:
# [1] 1000    9

# %%
 head(InsectSprays)
boxplot(split(InsectSprays$count, InsectSprays$spray))
# Out:
#   count spray
# 1 10    A
# 2  7    A
# 3 20    A
# 4 14    A
# 5 14    A
# 6 12    A
# plot without title

# %%
# Out:
# Warning message in download.file(url, destfile = "./data_download/elic_2016_1.RData", :
# “URL https://github.com/pbpearman/r-consortium-proposal/blob/interactive/material/lessons/switzerland-dual-use/data_clean/elic_2016_1.RData?raw=true: cannot open destfile './data_download/elic_2016_1.RData', reason 'No such file or directory'”
# Warning message in download.file(url, destfile = "./data_download/elic_2016_1.RData", :
# “download had nonzero exit status”
# Warning message in readChar(con, 5L, useBytes = TRUE):
# “cannot open compressed file './data_download/elic_2016_1.RData', probable reason 'No such file or directory'”
# Error in readChar(con, 5L, useBytes = TRUE): cannot open the connection
# Traceback:
#
# 1. load("./data_download/elic_2016_1.RData")
# 2. readChar(con, 5L, useBytes = TRUE)

# %%
# Out:
# [1] 0
